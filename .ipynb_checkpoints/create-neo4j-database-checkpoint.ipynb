# %%
from neo4j import GraphDatabase

uri = "neo4j://10.195.9.174:7687"
username = "neo4j"
password = "neo4j"

driver = GraphDatabase.driver(uri, auth=(username, password))

# %%
import json

data = json.load(open("T-Rex-Sample-Data.json", "r+"))

# %%
[a for a in data[7]['triples'] if a['predicate']['surfaceform'] is not None][0]
# Out:
# {'sentence_id': 2,
#  'predicate': {'boundaries': [237, 246],
#   'surfaceform': 'known for',
#   'uri': 'http://www.wikidata.org/prop/direct/P800',
#   'annotator': 'Wikidata_Property_Linker'},
#  'object': {'boundaries': [276, 292],
#   'surfaceform': 'The Fountainhead',
#   'uri': 'http://www.wikidata.org/entity/Q612688',
#   'annotator': 'Wikidata_Spotlight_Entity_Linker'},
#  'dependency_path': None,
#  'confidence': None,
#  'subject': {'boundaries': [230, 233],
#   'surfaceform': 'She',
#   'uri': 'http://www.wikidata.org/entity/Q132524',
#   'annotator': 'Simple_Coreference'},
#  'annotator': 'SPOAligner'}

# %%
data[3]
# Out:
# {'docid': 'http://www.wikidata.org/entity/Q19033',
#  'title': 'Arithmetic mean',
# ...

# %%
import pandas as pd

oldlist = pd.read_csv("C:\\Users\\96181\\Desktop\\subscribed_members_export_df92af051b.csv")
newlist = pd.read_csv("C:\\Users\\96181\\Desktop\\subscribed_segment_export_902705958f.csv")
newlist
# Out:
#                                  Email Address  First Name  Last Name  \
# 0                     wiesinger.mira@gmail.com        Mira  Wiesinger
# 1                   theresa.pichler@glamour.de     Theresa    Pichler
# 2         Russna.Jaswal@Goodlifepublishing.com      Russna     Jaswal
# 3                              sina@oor.berlin        Sina        NaN
# 4                   claudia.beran@condenast.de     Claudia      Beran
# ..                                         ...         ...        ...
# 160               konstantin.spachis@madame.de  Konstantin        NaN
# 161              sabine.hofmann@funkemedien.de  Dr. Sabine    Hofmann
# 162         sabrina.ussmueller@bunte.burda.com     Sabrina        NaN
# 163    philippe.saade@advisoryboard-agency.com    Philippe        NaN
# 164  marco.rechenberg@advisoryboard-agency.com       Marco        NaN
#
#      Address  Phone Number                   Greeting  MEMBER_RATING  \
# ...

# %%
newlist[~newlist['Email Address'].isin(oldlist['Email Address'])]
# Out:
#                              Email Address First Name     Last Name  Address  \
# 0                 wiesinger.mira@gmail.com       Mira     Wiesinger      NaN
# 1               theresa.pichler@glamour.de    Theresa       Pichler      NaN
# 2     Russna.Jaswal@Goodlifepublishing.com     Russna        Jaswal      NaN
# 3                          sina@oor.berlin       Sina           NaN      NaN
# 4               claudia.beran@condenast.de    Claudia         Beran      NaN
# 5          florian.boitin@kouneli-media.de    Florian        Boitin      NaN
# 6                    tobias.frericks@gq.de     Tobias           NaN      NaN
# 7                Felix.wagner@admagazin.de      Felix        Wagner      NaN
# 49                    kira@plasticmedia.eu       Kira  Stachowitsch      NaN
# 62   danielle.grosch-ruppersberg@madame.de   Danielle           NaN      NaN
# 94              voss@blickpunktjuwelier.de     Ulrich          Voss      NaN
# ...
